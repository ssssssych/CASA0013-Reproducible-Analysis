# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet

from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

from scipy import stats

# %%
#Reading Dataset
df = pd.read_csv("housedata.csv")

# %%
# Little peek into the dataset
df.head()
# Out:
#    Unnamed: 0                  NAME   GSS_CODE  house_price2021_2016  \
# 0           1        City of London  E09000001                 -5851
# 1           2  Barking and Dagenham  E09000002                 42588
# 2           3                Barnet  E09000003                 24789
# 3           4                Bexley  E09000004                 44446
# 4           5                 Brent  E09000005                 24268
#
#    distance_borough  airbnb2021_2016
# 0           0.00000        87.748106
# 1       16021.55849        25.401628
# 2       13907.48287        69.408519
# 3       17309.95817        22.229618
# 4       13118.91373        60.122510

# %%
#Checking for duplicated entries
sum(df.duplicated(df.columns))
# Out:
# 0

# %%
#shape of dataset
df.shape
# Out:
# (33, 6)

# %%
#Description of every column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            33 non-null     int64
#  1   NAME                  33 non-null     object
#  2   GSS_CODE              33 non-null     object
#  3   house_price2021_2016  33 non-null     int64
#  4   distance_borough      33 non-null     float64
#  5   airbnb2021_2016       33 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.7+ KB

# %%
#Dropping as it looks like an iterator
del df['Unnamed: 0']

# %%
#correlation between the features
corr = df.corr()
sns.heatmap(corr,cmap = "crest")
# Out:
# <AxesSubplot:>

# %%
#numeric correlation
corr['house_price2021_2016'].sort_values(ascending=False)
# Out:
# house_price2021_2016    1.000000
# distance_borough        0.410294
# airbnb2021_2016        -0.643910
# Name: house_price2021_2016, dtype: float64

# %%
numeric_data=df.select_dtypes(include=[np.number])
numeric_data.describe()
# Out:
#        house_price2021_2016  distance_borough  airbnb2021_2016
# count             33.000000         33.000000        33.000000
# mean           32137.757576      12330.970666        37.765667
# std            21088.922224       6221.608674        23.164838
# min           -32766.000000          0.000000        11.914398
# 25%            24789.000000       7136.217753        22.229618
# 50%            36873.000000      13118.913730        27.978893
# 75%            45581.000000      17338.129690        45.996884
# max            64459.000000      24704.899110       103.184827

# %%
plt.figure(figsize=(15,6))

sns.boxplot(x='house_price2021_2016', data=df)
plt.ticklabel_format(style='plain', axis='x')
plt.title('Boxplot of HOUSE PRICE')
plt.show()

# %%
sns.distplot(df['house_price2021_2016'])
# Out:
# <AxesSubplot:xlabel='house_price2021_2016', ylabel='Density'>

# %%
# Remove observations that fall outside those caps
data = df[(df['house_price2021_2016'] > -20000) & (df['house_price2021_2016'] < 10000)]

# %%
#skewness of SalePrice
data['house_price2021_2016'].skew()
# Out:
# 0.017998781428267826

# %%
sales=np.log(data['house_price2021_2016'])
print(sales.skew())
sns.distplot(sales)
# Out:
# 0.7089772681677613
# <AxesSubplot:xlabel='house_price2021_2016', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='airbnb2021_2016', y='house_price2021_2016', data=data, fit_reg=False, scatter_kws={'alpha':0.3})
# Out:
# <AxesSubplot:xlabel='airbnb2021_2016', ylabel='house_price2021_2016'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='airbnb2021_2016', y='house_price2021_2016', data=df)
plt.title('Airbnb Price vs House Price')
plt.show()

# %%
Y_df = df['house_price2021_2016']
X_df = df.drop('house_price2021_2016', axis=1)

X_df.shape , Y_df.shape
# Out:
# ((33, 4), (33,))

# %%
X_train ,X_test, Y_train , Y_test = train_test_split(X_df , Y_df , test_size = 0.3 , random_state =34)

# %%
# Training set
X_train.shape , Y_train.shape
# Out:
# ((23, 4), (23,))

# %%
#Testing set
X_test.shape , Y_test.shape
# Out:
# ((10, 4), (10,))

# %%
# RMSE
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))

# %%
rf_regr = RandomForestRegressor()
rf_regr.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 rf_regr = RandomForestRegressor()
# ----> 2 rf_regr.fit(X_train, Y_train)
#       3 Y_pred_rf = rf_regr.predict(X_test)
#       4 rmse(Y_test,Y_pred_rf)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       1 import statsmodels.api as sm
# ----> 2 x = sm.add_constant(x)
#       3 from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
#       5 features=x.columns
#
# NameError: name 'x' is not defined
